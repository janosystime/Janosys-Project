# %% [markdown]
# <a href="https://colab.research.google.com/github/janosystime/Janosys-Project/blob/backend/bd%5CBackEnd_Janosys_1_Sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Descrições**
# Project description

# %% [markdown]
# ## Importação das bibliotecas Pandas e Plotly.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ##Importação dos dados do GitHub

# %%
df = pd.DataFrame(pd.read_csv('https://github.com/janosystime/Janosys-Project/blob/main/bd/mockado_df.csv?raw=true', encoding='latin1', sep=';'))

# %% [markdown]
# ##Exibição do DataFrame Bruto e informação das colunas.

# %%
display(df.head())
display(df.info())
# Out:
#                  Regiao   Infantil 2010  Crianca 2010  Adolescente 2010  \
# 0                Centro           4.327         7.212             7.933
# 1                 Leste           9.659        16.099            17.709
# 2                 Norte           3.588         5.980             6.578
# 3                 Oeste           2.470         4.116             4.528
# 4  Sao Francisco Xavier          81.000       134.000           148.000
#
#    Adulto 2010  Idoso 2010  CENSO 2010  Infantil 2022  Crianca 2022  \
# 0       48.317       4.326      72.115          3.620         5.792
# 1      107.863       9.660     160.990          9.073        14.517
# 2       40.066       3.588      59.800          3.089         4.942
# 3       27.578       2.469      41.161          3.224         5.159
# 4      898.000      81.000       1.342         72.000       115.000
#
#    Adolescente 2022  Adulto 2022  Idoso 2022  CENSO 2022  Crescimento  \
# ...

# %% [markdown]
# ##Filtragem e exibição do Dataframe por Região e Faixa-Etária

# %%
totalRegioes_df = df[['Regiao', 'CENSO 2010', 'CENSO 2022']]

display(totalRegioes_df.head())
# Out:
#                  Regiao  CENSO 2010  CENSO 2022
# 0                Centro      72.115      72.401
# 1                 Leste     160.990     181.463
# 2                 Norte      59.800      61.780
# 3                 Oeste      41.161      64.482
# 4  Sao Francisco Xavier       1.342       1.443

# %% [markdown]
# ##Definindo gráfico no plotly com base nos filtros escolhidos.

# %%
fig = px.bar(totalRegioes_df, x='Regiao', y=['CENSO 2010', 'CENSO 2022'], title='População por Região (2010 vs 2022)',
labels={'Diferença': 'Diferença de População', 'Regiao': 'Região'}, barmode='group', text_auto='.2s', color_discrete_sequence=['#A8C8FF','#FFF5B1'])
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Exibição do gráfico gerado.

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
